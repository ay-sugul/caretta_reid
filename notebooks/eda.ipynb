# %% [markdown]
# # Caretta Re-ID EDA
#
# This notebook is a lightweight entry point for inspecting the SeaTurtleID2022 dataset, split definitions, and annotation structure.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
metadata_splits = pd.read_csv(root / 'data' / 'raw' / 'metadata_splits.csv')
metadata_splits.head()

# %%
metadata_splits['identity'].value_counts().head(10)
